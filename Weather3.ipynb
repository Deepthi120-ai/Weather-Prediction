# %% [markdown]
# <a href="https://colab.research.google.com/github/Deepthi120-ai/Weather-Prediction/blob/main/Weather3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from matplotlib.pylab import rcParams

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7885d40a-c025-4d40-ae1d-973a44107e0d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7885d40a-c025-4d40-ae1d-973a44107e0d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Delhi_dataset.xls to Delhi_dataset.xls

# %%
data=pd.read_excel('Delhi_dataset.xls')

# %%
import pandas as pd
import datetime as dt
df=data
d=int(input("enter day:\n"))
m=int(input("enter month:\n"))
y=int(input("enter year:\n"))

date=dt.datetime(y,m,d)
print(date)

x=pd.Timestamp(date).to_period(freq ='M')
obs= df[df['Datetime'].dt.to_period('M').between(x,x)]
obs.set_index('Datetime',inplace=True)
# Out:
# enter day:
# 9
# enter month:
# 9
# enter year:
# 2016
# 2016-09-09 00:00:00

# %%
import scipy
plt.rcParams["figure.figsize"] = (15, 6)
mean=obs["Temperature"].mean()
std=obs["Temperature"].std()
obs.sort_values(by="Temperature",inplace=True)
x_values=obs["Temperature"]
y_values=scipy.stats.norm(mean, std)
plt.plot(x_values, y_values.pdf(x_values))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
import scipy
plt.rcParams["figure.figsize"] = (15, 6)

indexnames=obs[obs.Pressure==obs.Pressure.max()].index
obs.drop(indexnames,inplace=True)

mean=obs["Pressure"].mean()
std=obs["Pressure"].std()
obs.sort_values(by="Pressure",inplace=True)
x_values=obs["Pressure"]
y_values=scipy.stats.norm(mean, std)
plt.plot(x_values, y_values.pdf(x_values))
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
import scipy
plt.rcParams["figure.figsize"] = (15, 6)
mean=obs["Dew-point"].mean()
std=obs["Dew-point"].std()
obs.sort_values(by="Dew-point",inplace=True)
x_values=obs["Dew-point"]
y_values=scipy.stats.norm(mean, std)
plt.plot(x_values, y_values.pdf(x_values))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
import scipy
plt.rcParams["figure.figsize"] = (15, 6)
mean=obs["Humidity"].mean()
std=obs["Humidity"].std()
obs.sort_values(by="Humidity",inplace=True)
x_values=obs["Humidity"]
y_values=scipy.stats.norm(mean, std)
plt.plot(x_values, y_values.pdf(x_values))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
z_values=scipy.stats.zscore(obs["Temperature"])

# %%
n=int(obs["Temperature"].count())
mean=obs["Temperature"].mean()
std=obs["Temperature"].std()
z=list()
for i in range(n):
  z.append((obs["Temperature"][i]-mean)/std)

# %%
#Temperature value assumed as 38 

mean=obs["Temperature"].mean()
std=obs["Temperature"].std()
zv1=(mean-38)/std
zv1
# Out:
# -2.1016749810666253

# %%
#Humidity value assumed 33
mean=obs["Humidity"].mean()
std=obs["Humidity"].std()
zv2=(mean-33)/std
zv2
# Out:
# 2.0157284515035268

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,10))
plt.title("Weather conditions")
obs['Weather'].value_counts().plot(kind="pie", autopct='%1.2f%%')
plt.plot()
# Out:
# []
